# %%
# 0314 v1 - 가까운 두 개 마커로 위치 파악

# %%
import cv2
import cv2.aruco as aruco
import numpy as np

# 1) 카메라 내부 파라미터 (예시)
cameraMatrix = np.array([[1400, 0, 640],
                         [0, 1400, 360],
                         [0, 0, 1]], dtype=np.float32)
distCoeffs = np.zeros((5,), dtype=np.float32)  # 왜곡 계수(없는 경우)

# 2) 마커 실제 한 변 길이 (단위 m)
marker_length = 0.16

# 3) ArUco 사전, 파라미터 생성

aruco_dict = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)

detector_params = aruco.DetectorParameters()  # 예전 방식


# 4) 월드 좌표에서 마커의 위치(0~11번)
marker_world_pos = {
    0: np.array([0.0,  0.0, 0.0]),
    1: np.array([1.5,  0.0, 0.0]),
    2: np.array([3.0,  0.0, 0.0]),
    3: np.array([4.5,  0.0, 0.0]),
    4: np.array([0.0,  1.5, 0.0]),
    5: np.array([1.5,  1.5, 0.0]),
    6: np.array([3.0,  1.5, 0.0]),
    7: np.array([4.5,  1.5, 0.0]),
    8: np.array([0.0,  3.0, 0.0]),
    9: np.array([1.5,  3.0, 0.0]),
    10: np.array([3.0,  3.0, 0.0]),
    11: np.array([4.5,  3.0, 0.0]),
}

def compute_camera_pos(marker_id, rvec, tvec, marker_world):
    """
    단일 마커의 pose (rvec, tvec) + 해당 마커의 월드 좌표 -> 카메라 월드 위치 추정
    """
    R, _ = cv2.Rodrigues(rvec)        # (3,3)
    t = tvec.reshape(3, 1)            # (3,1)
    cam_in_marker = -R.T @ t          # (3,1)
    return marker_world.reshape(3, 1) + cam_in_marker

# 5) 카메라 열기
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_EXPOSURE, -4)

if not cap.isOpened():
    print("카메라를 열 수 없습니다.")
    exit()

while True:
    ret, frame = cap.read()
    if not ret:
        print("프레임 읽기 실패!")
        break

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 6) ArUco 마커 검출
    corners, ids, rejected = aruco.detectMarkers(
        gray, aruco_dict, parameters=detector_params
    )

    if ids is not None:
        # 마커 그리기
        aruco.drawDetectedMarkers(frame, corners, ids)

        # 7) Pose 추정
        rvecs, tvecs, _ = aruco.estimatePoseSingleMarkers(
            corners, marker_length, cameraMatrix, distCoeffs
        )

        # 마커 ID와 위치 표시
        for i, id_ in enumerate(ids):
            c = corners[i][0][0]
            cv2.putText(frame, f"ID {id_[0]}", (int(c[0]), int(c[1] - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

        # -------------------
        # [핵심] 가까운 두 마커로 카메라 위치 추정
        # -------------------
        if len(ids) >= 2:
            found_ids = ids.flatten()
            cam_positions = []

            # ID와 (rvec, tvec) 매핑
            id_to_pose = {id_[0]: (rvecs[i], tvecs[i]) for i, id_ in enumerate(ids)}

            # 월드 좌표 등록된 마커만 필터링
            valid_markers = [(id_, id_to_pose[id_][1]) for id_ in found_ids if id_ in marker_world_pos]

            if len(valid_markers) >= 2:
                # 거리순 (가까운 순)으로 정렬
                valid_markers.sort(key=lambda x: np.linalg.norm(x[1]))

                # 가까운 두 개 선택
                selected_ids = [valid_markers[0][0], valid_markers[1][0]]
                print(f"[INFO] Selected markers for position estimation: {selected_ids}")

                # 카메라 위치 계산
                for m_id in selected_ids:
                    rvec, tvec = id_to_pose[m_id]
                    world_pos = marker_world_pos[m_id]
                    cam_pos = compute_camera_pos(m_id, rvec, tvec, world_pos)
                    cam_positions.append(cam_pos)

                # 두 위치 평균
                camera_world_pos = np.mean(cam_positions, axis=0)
                cx, cy, cz = camera_world_pos.ravel()
                print(f"[INFO] Camera world position estimated: ({cx:.2f}, {cy:.2f}, {cz:.2f})")
    # -------------------

    # 화면 표시
    cv2.imshow("Aruco Marker Tracking", frame)
    if cv2.waitKey(1) & 0xFF == 27:  # ESC 누르면 종료
        break

# 종료
cap.release()
cv2.destroyAllWindows()
# Out:
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.45, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.45, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.39, 0.06, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.39, 0.06, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -0.58, 4.39)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -0.58, 4.39)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.33, -0.65, 4.26)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.33, -0.65, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.42, -0.79, 4.33)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.42, -0.79, 4.33)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.70, -0.87, 4.28)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.70, -0.87, 4.28)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.39, -0.98, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.27, 4.32)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.27, 4.32)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.63, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.63, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.72, 1.55, 3.83)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.72, 1.55, 3.83)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.85, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.85, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.86, 1.60, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.86, 1.60, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.61, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.61, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.81, 1.44, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.81, 1.44, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.43, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.43, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.86, -1.37, 3.56)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.52, 3.88)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.52, 3.88)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.93, 1.76, 3.81)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.93, 1.76, 3.81)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.81, 1.42, 3.68)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.81, 1.42, 3.68)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -1.38, 3.71)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -1.38, 3.71)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.25, -0.02, 3.72)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.25, -0.02, 3.72)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.65, -1.05, 3.86)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.65, -1.05, 3.86)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.59, -1.06, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.96, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.96, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -1.05, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -1.05, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -1.09, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -1.09, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.00, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.85, 1.58, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.85, 1.58, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -1.06, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -1.06, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.70, -1.01, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.70, -1.01, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.02, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.02, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.03, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.03, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.85, 1.74, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.85, 1.74, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.91, 1.69, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.91, 1.69, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.83, 1.72, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.83, 1.72, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.99, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.99, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -1.06, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -1.03, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -1.03, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -0.91, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -0.91, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -1.04, 3.93)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -1.04, 3.93)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -1.21, 3.85)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -1.21, 3.85)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.94, 1.48, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.94, 1.48, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.87, 1.69, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.87, 1.69, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -1.07, 3.93)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.70, -1.01, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.70, -1.01, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.91, 1.71, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.91, 1.71, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.67, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.67, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.72, -1.01, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.72, -1.01, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -1.00, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -1.00, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -0.92, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -0.92, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -1.15, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.59, -1.09, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.59, -1.09, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.95, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.95, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.87, 1.70, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.87, 1.70, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -0.99, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -0.99, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.65, -0.97, 4.06)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.65, -0.97, 4.06)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.80, 1.70, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.80, 1.70, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.62, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.62, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -1.01, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -1.01, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -1.08, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -1.08, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.01, 3.99)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -1.01, 3.99)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.85, 1.81, 4.03)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.85, 1.81, 4.03)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -1.00, 3.99)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.86, 1.56, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.86, 1.56, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -1.03, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -1.03, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -1.04, 4.09)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -1.04, 4.09)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -1.08, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -1.08, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.84, 1.28, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.84, 1.28, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.91, 1.34, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -1.08, 4.01)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -1.08, 4.01)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.65, -0.92, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.65, -0.92, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.98, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.98, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.84, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.84, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.25, 1.03, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.25, 1.03, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -0.90, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -0.90, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.99, 1.92, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.99, 1.92, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.86, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.86, 4.24)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.51, -0.91, 4.29)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.51, -0.91, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.01, 1.14, 4.43)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.01, 1.14, 4.43)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -1.05, 4.38)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -1.05, 4.38)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.58, -0.71, 4.16)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.41, -0.09, 3.87)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.41, -0.09, 3.87)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.71, -0.81, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.71, -0.81, 4.23)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.58, -0.86, 4.32)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.58, -0.86, 4.32)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.29, 0.71, 4.09)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.29, 0.71, 4.09)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.86, 1.06, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.86, 1.06, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.85, 4.30)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.85, 4.30)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.59, -0.53, 4.20)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.59, -0.53, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.97, 4.02)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.97, 4.02)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.91, -1.06, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.91, -1.06, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.92, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.84, 3.81)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.63, -0.84, 3.81)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.36, -0.90, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.36, -0.90, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.19, -0.04, 3.86)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.19, -0.04, 3.86)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.22, -0.08, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.22, -0.08, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.15, 2.13, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.15, 2.13, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.15, 2.11, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.15, 2.11, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.99, 1.95, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.99, 1.95, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -0.99, 4.32)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.73, 1.64, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.73, 1.64, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.15, 1.81, 4.34)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.15, 1.81, 4.34)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.85, -0.94, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.85, -0.94, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.99, 2.08, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.99, 2.08, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.47, -1.09, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.47, -1.09, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.24, 1.94, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.24, 1.94, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.73, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.01, 1.67, 4.30)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.01, 1.67, 4.30)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.42, 4.04)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.82, 1.42, 4.04)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.39, -0.99, 4.28)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.39, -0.99, 4.28)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.35, 1.98, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.35, 1.98, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.23, 1.92, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.23, 1.92, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.81, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.81, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.26, 1.90, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.34, 1.90, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.34, 1.90, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.11, 1.76, 4.36)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.11, 1.76, 4.36)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -0.68, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -0.68, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.50, -0.75, 4.30)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.50, -0.75, 4.30)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.98, 0.64, 4.36)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.98, 0.64, 4.36)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.50, -0.72, 4.31)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.50, -0.72, 4.31)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -1.08, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.68, -1.08, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -1.01, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -1.01, 4.20)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.50, -0.85, 4.27)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.23, 1.68, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.23, 1.68, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.21, 1.92, 4.09)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.21, 1.92, 4.09)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.07, 1.31, 4.38)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (6.07, 1.31, 4.38)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.44, -0.80, 4.38)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.41, 1.53, 4.26)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.41, 1.53, 4.26)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.41, -0.54, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.41, -0.54, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.37, 1.70, 4.33)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.37, 1.70, 4.33)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.44, -0.78, 4.39)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.44, -0.78, 4.39)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.51, -0.75, 4.32)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.51, -0.75, 4.32)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.54, -0.51, 4.35)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.54, -0.51, 4.35)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.58, -0.53, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.58, -0.53, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.42, -0.62, 4.43)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.42, -0.62, 4.43)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.11, 1.73, 4.26)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (5.94, 1.61, 4.41)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (5.94, 1.61, 4.41)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.60, -0.89, 4.39)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.60, -0.89, 4.39)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.48, -0.61, 4.37)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.48, -0.61, 4.37)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.10, 1.56, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (6.10, 1.56, 4.34)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.49, -0.48, 4.12)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.49, -0.48, 4.12)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.90, -0.92, 4.40)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (3.90, -0.92, 4.40)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.67, -0.70, 3.18)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (4.67, -0.70, 3.18)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -0.74, 3.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -0.74, 3.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.78, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.78, 4.08)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.56, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.56, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.75, 4.10)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.77, 1.62, 4.03)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.77, 1.62, 4.03)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.52, 1.60, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.52, 1.60, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.35, -0.85, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.35, -0.85, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.83, 1.66, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.83, 1.66, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.28, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.28, 4.05)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.68, 1.62, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.75, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.75, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.82, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.82, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.84, 1.48, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.84, 1.48, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.40, -0.63, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.40, -0.63, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.46, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.46, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.46, 1.38, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.46, 1.38, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.81, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.81, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.70, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.70, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.66, 4.18)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.52, 1.69, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.52, 1.69, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.34, -0.75, 4.31)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.34, -0.75, 4.31)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.81, 1.55, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.81, 1.55, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.72, 1.44, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.72, 1.44, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.82, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.82, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.46, -0.71, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.46, -0.71, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.79, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.79, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.71, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.71, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.51, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.62, 1.50, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.62, 1.50, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.53, -0.62, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.53, -0.62, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.52, -0.70, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.52, -0.70, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.45, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.45, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.50, -0.74, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.50, -0.74, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.59, 1.60, 4.28)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.63, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.63, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.62, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.62, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.64, 1.44, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.64, 1.44, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.73, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.73, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.76, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.76, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.67, 1.56, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.67, 1.56, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.62, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.62, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.74, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.74, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.59, 1.63, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.52, -0.64, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.52, -0.64, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.60, -0.66, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.60, -0.66, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.60, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.60, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.43, -0.87, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.43, -0.87, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.75, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.75, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.51, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.51, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.34, -0.90, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.34, -0.90, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.73, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.73, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.81, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.81, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.77, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.77, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.63, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.63, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.64, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.64, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.59, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.59, 4.29)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.80, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.80, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.64, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.64, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.64, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.64, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.64, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.67, 1.73, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.67, 1.73, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.75, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.75, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.47, -0.70, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.47, -0.70, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.69, 4.18)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.69, 4.18)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -0.80, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.61, -0.80, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.58, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.42, -0.76, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.42, -0.76, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.58, 1.59, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.58, 1.59, 4.15)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -0.65, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.64, -0.65, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.77, 1.81, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.77, 1.81, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.47, -0.69, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.47, -0.69, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.36, -0.72, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.36, -0.72, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.54, 4.24)
# ...
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.36, -0.72, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.36, -0.72, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.45, 1.66, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.45, 1.66, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.77, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.77, 4.27)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.62, 1.63, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.62, 1.63, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.62, 1.63, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.51, 1.61, 4.26)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -0.66, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -0.66, 4.13)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.75, 1.72, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.75, 1.72, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.63, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.63, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.64, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.64, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.61, 1.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.61, 1.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.69, -0.74, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.50, 4.18)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.50, 4.18)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.73, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.73, 4.19)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.59, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.59, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, 2.27, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, 2.27, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.74, 1.63, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.74, 1.63, 4.16)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.64, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.76, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.76, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.67, 1.74, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.67, 1.74, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.64, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.49, -0.64, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.59, 1.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.59, 1.74, 4.25)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.21)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.74, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.48, -0.74, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.76, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.37, -0.76, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.55, -0.69, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.60, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.60, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.73, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.60, 1.73, 4.22)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.74, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.70, 1.74, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.64, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.64, 4.20)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.74, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.66, 1.74, 4.23)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.59, 1.66, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.59, 1.66, 4.24)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.74, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.56, -0.74, 4.17)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.67, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.69, 1.67, 4.14)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.48, 1.29, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.48, 1.29, 4.11)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.26, 1.34, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.46, -1.16, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.46, -1.16, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.74, 1.64, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.74, 1.64, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.74, 1.64, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.74, 1.64, 4.07)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.53, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.54, 1.53, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.75, -1.13, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.75, -1.13, 3.89)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.76, 1.57, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.76, 1.57, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.68, 1.64, 4.06)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.72, 1.41, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.72, 1.41, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.71, 1.42, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.71, 1.42, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.48, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.63, 1.48, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.59, -0.88, 3.99)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.59, -0.88, 3.99)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.84, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.84, 4.00)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.87, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.54, -0.87, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.60, -0.94, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.77, 1.58, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.77, 1.58, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.86, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.58, -0.86, 3.98)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.84, 1.60, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.84, 1.60, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.45, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.78, 1.45, 3.92)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.79, 1.60, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.79, 1.60, 3.96)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.78, 4.01)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.45, -0.78, 4.01)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.94, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.57, -0.94, 3.91)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -0.91, 3.88)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.66, -0.91, 3.88)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.53, -0.80, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.53, -0.80, 3.94)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.47, 3.85)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.47, 3.85)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -0.88, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.62, -0.88, 3.97)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (4.52, -0.80, 3.95)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.64, 1.49, 3.90)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.64, 1.49, 3.90)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.58, 3.76)
# [INFO] Selected markers for position estimation: [7, 3]
# [INFO] Camera world position estimated: (5.65, 1.58, 3.76)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (3.72, 0.32, 3.67)
# [INFO] Selected markers for position estimation: [3, 7]
# [INFO] Camera world position estimated: (3.72, 0.32, 3.67)
# [INFO] Selected markers for position estimation: [7, 9]
# [INFO] Camera world position estimated: (-1.32, 3.39, 3.64)
# [INFO] Selected markers for position estimation: [7, 9]
# [INFO] Camera world position estimated: (-1.32, 3.39, 3.64)
# [INFO] Selected markers for position estimation: [7, 5]
# [INFO] Camera world position estimated: (9.42, 0.99, 3.59)
# [INFO] Selected markers for position estimation: [7, 5]
# [INFO] Camera world position estimated: (9.42, 0.99, 3.59)
# [INFO] Selected markers for position estimation: [7, 5]
# [INFO] Camera world position estimated: (-0.74, 1.13, 3.63)
