# %%
# 0314 v2 - 가까운 두 개 마커로 위치 파악
# 마커 개수 늘림 시야에 3개까지 잘 잡히는데 가까운 2개를 고르려다 보니까 어떤 마커 2개를 고르는지에 따라서 좌표가 다르게 나타남
#v3: 여러개 중에 2개씩 이용해서 위치 뽑고 평균 내기
#v4: 칼만 필터  - v3보다 개선됨 (튀는 값이 줄어들었지만 여전히 많긴 함)

# 0317 v1: z축 거리 고정해서 입력하기 + 칼만필터까지 적용
# 정확도 높음 z값 -1.8m로 했는데 로봇에 부착하고 다시 거리 재보면 될듯
# v2: 마커 17번 빠졌던 거 추가
# v3: 마커 z축 회전 정렬 
#v4: 회전 정렬 결과 나타나게 opencv 3d 축 그리기 반영
# v5: 로봇 제어를 위한 yaw 행렬 추출  -- 아직 안됨 아래 코드 실행해보고 수정할 것 


# 0505 v1: 로봇 제어를 위한 yaw 행렬 추출 부터 ( 단, Euler 변환까지 적용)

## 성공 - 마커 90도씩 돌려보면 결과 잘 나옴 (천장 마커로는 아직 테스트 못함

# 0516 : 추출한 행렬가지고 로봇 제어 시도
# yaw 추출 
# 다중 waypoint 설정해서 움직임 제어


#v2:ros에 전달하기

# %%
#!/usr/bin/env python
import cv2
import cv2.aruco as aruco
import numpy as np
import math
import rospy
from geometry_msgs.msg import Pose2D
from scipy.spatial.transform import Rotation as R

# ===========================
# 📌 1. ROS & ArUco Localization Node
# ===========================
rospy.init_node("camera_localization_node")
pose_pub = rospy.Publisher("/robot_pose", Pose2D, queue_size=10)

# Calibration
cameraMatrix = np.load('C:/cal_cam/calibration_matrix.npy')
distCoeffs = np.load('C:/cal_cam/distortion_coefficients.npy')
marker_length = 0.16  # meters
FIXED_Z = -1.8

# Marker positions
marker_world_pos = {
    0: np.array([0.0, 0.0, 0.0]), 1: np.array([1.5, 0.0, 0.0]),
    2: np.array([3.0, 0.0, 0.0]), 3: np.array([4.5, 0.0, 0.0]),
    4: np.array([0.0, 1.5, 0.0]), 5: np.array([1.5, 1.5, 0.0]),
    6: np.array([3.0, 1.5, 0.0]), 7: np.array([4.5, 1.5, 0.0]),
    8: np.array([0.0, 3.0, 0.0]), 9: np.array([1.5, 3.0, 0.0]),
    10: np.array([3.0, 3.0, 0.0]), 11: np.array([4.5, 3.0, 0.0]),
    12: np.array([0.7, 0.7, 0.0]), 13: np.array([2.3, 0.7, 0.0]),
    14: np.array([3.7, 0.7, 0.0]), 15: np.array([0.7, 2.3, 0.0]),
    16: np.array([2.3, 2.3, 0.0]), 17: np.array([3.7, 2.3, 0.0])
}

marker_orientation = {
    0: 0, 1: 0, 2: -180, 3: 0, 4: -180, 5: -180, 6: 0, 7: -180,
    8: 0, 9: 0, 10: -180, 11: 0, 12: -180, 13: -90, 14: -270,
    15: 0, 16: -90, 17: -90
}

def get_z_rotation_matrix(degrees):
    return R.from_euler('z', degrees, degrees=True).as_matrix()

# Video source
cap = cv2.VideoCapture(0)
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)
cap.set(cv2.CAP_PROP_EXPOSURE, -4)

aruco_dict = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)
detector_params = aruco.DetectorParameters()

while not rospy.is_shutdown():
    ret, frame = cap.read()
    if not ret:
        continue

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    corners, ids, _ = aruco.detectMarkers(gray, aruco_dict, parameters=detector_params)

    if ids is not None:
        aruco.drawDetectedMarkers(frame, corners, ids)
        rvecs, tvecs, _ = aruco.estimatePoseSingleMarkers(corners, marker_length, cameraMatrix, distCoeffs)

        cam_positions, yaws, weights = [], [], []

        for i, m_id in enumerate(ids.flatten()):
            if m_id in marker_world_pos:
                rvec, tvec = rvecs[i], tvecs[i]
                world_pos = marker_world_pos[m_id]

                R_marker, _ = cv2.Rodrigues(rvec)
                correction_R = get_z_rotation_matrix(marker_orientation.get(m_id, 0))
                R_corrected = correction_R @ R_marker
                rvec_corrected, _ = cv2.Rodrigues(R_corrected)

                cv2.drawFrameAxes(frame, cameraMatrix, distCoeffs, rvec_corrected, tvec, 0.1)

                yaw = R.from_matrix(R_corrected).as_euler('xyz', degrees=False)[2]
                yaws.append(yaw)

                cam_pos = -R_marker.T @ tvec.reshape(3, 1)
                cam_pos[2] = FIXED_Z
                cam_pos = (correction_R @ cam_pos + world_pos.reshape(3, 1)).flatten()

                cam_positions.append(cam_pos)
                weights.append(1.0 / (np.linalg.norm(tvec) + 1e-6))

        weights = np.array(weights)
        weights /= np.sum(weights)
        camera_world_pos = np.average(cam_positions, axis=0, weights=weights)
        camera_yaw = np.average(yaws, weights=weights)

        pose_msg = Pose2D()
        pose_msg.x = float(camera_world_pos[0])
        pose_msg.y = float(camera_world_pos[1])
        pose_msg.theta = float(camera_yaw)

        pose_pub.publish(pose_msg)

        # Overlay text
        text = f"X={pose_msg.x:.2f} Y={pose_msg.y:.2f} Yaw={math.degrees(pose_msg.theta):.2f}deg"
        cv2.putText(frame, text, (30, 40), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 255), 2)

    cv2.imshow("Aruco Localization", frame)
    if cv2.waitKey(1) & 0xFF == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_8004\725015293.py:136: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cx = float(cx)
# C:\Users\user\AppData\Local\Temp\ipykernel_8004\725015293.py:137: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cy = float(cy)
# C:\Users\user\AppData\Local\Temp\ipykernel_8004\725015293.py:138: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   cz = float(cz)
# [INFO] Position: (0.00, 0.00, 0.00), Yaw: -1.56°
# [INFO] Position: (0.03, 0.00, -0.02), Yaw: -1.56°
# [INFO] Position: (0.14, -0.00, -0.09), Yaw: -0.77°
# [INFO] Position: (0.45, -0.00, -0.28), Yaw: 0.21°
# [INFO] Position: (1.04, -0.01, -0.63), Yaw: 0.21°
# [INFO] Position: (1.80, -0.02, -1.11), Yaw: 2.66°
# [INFO] Position: (2.56, -0.02, -1.57), Yaw: 2.66°
# [INFO] Position: (3.14, -0.02, -1.93), Yaw: 3.27°
# [INFO] Position: (3.50, -0.02, -2.16), Yaw: 3.27°
# [INFO] Position: (3.69, -0.02, -2.28), Yaw: 3.86°
# [INFO] Position: (3.74, -0.02, -2.31), Yaw: 3.86°
# [INFO] Position: (3.72, -0.01, -2.30), Yaw: 3.42°
# [INFO] Position: (3.64, -0.01, -2.25), Yaw: 3.42°
# [INFO] Position: (3.32, -0.01, -2.04), Yaw: -3.68°
# [INFO] Position: (3.21, -0.00, -1.97), Yaw: -3.68°
# [INFO] Position: (3.33, 0.00, -2.04), Yaw: 2.69°
# [INFO] Position: (3.23, 0.01, -1.97), Yaw: 2.12°
# [INFO] Position: (3.15, 0.02, -1.92), Yaw: 2.12°
# [INFO] Position: (3.09, 0.02, -1.88), Yaw: 1.78°
# [INFO] Position: (3.03, 0.02, -1.84), Yaw: 1.78°
# [INFO] Position: (3.00, 0.02, -1.82), Yaw: 2.43°
# [INFO] Position: (2.97, 0.02, -1.80), Yaw: 2.43°
# [INFO] Position: (2.95, 0.01, -1.79), Yaw: 3.15°
# [INFO] Position: (2.94, 0.01, -1.78), Yaw: 4.46°
# [INFO] Position: (2.94, 0.01, -1.78), Yaw: 4.46°
# [INFO] Position: (2.94, 0.01, -1.78), Yaw: 9.84°
# [INFO] Position: (2.94, 0.01, -1.78), Yaw: 9.84°
# [INFO] Position: (2.98, 0.02, -1.79), Yaw: 10.25°
# [INFO] Position: (3.00, 0.03, -1.79), Yaw: 10.25°
# [INFO] Position: (3.03, 0.02, -1.79), Yaw: 9.15°
# [INFO] Position: (3.05, 0.02, -1.79), Yaw: 9.15°
# [INFO] Position: (3.05, -0.00, -1.79), Yaw: 8.02°
# [INFO] Position: (3.05, -0.02, -1.80), Yaw: 5.78°
# [INFO] Position: (3.06, -0.03, -1.80), Yaw: 6.05°
# [INFO] Position: (3.06, -0.04, -1.80), Yaw: 6.05°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 5.69°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 5.69°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 4.74°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 4.74°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 3.35°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 3.35°
# [INFO] Position: (3.05, -0.05, -1.80), Yaw: 2.72°
# [INFO] Position: (3.05, -0.05, -1.80), Yaw: 2.52°
# [INFO] Position: (3.05, -0.05, -1.80), Yaw: 2.52°
# [INFO] Position: (3.05, -0.04, -1.80), Yaw: 3.58°
# [INFO] Position: (3.05, -0.04, -1.80), Yaw: 3.58°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 3.61°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 3.61°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 3.08°
# [INFO] Position: (3.04, -0.03, -1.80), Yaw: 3.08°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 3.73°
# [INFO] Position: (3.05, -0.04, -1.80), Yaw: 3.73°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 5.79°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 5.79°
# [INFO] Position: (3.06, -0.03, -1.80), Yaw: 5.15°
# [INFO] Position: (3.06, -0.03, -1.80), Yaw: 5.15°
# [INFO] Position: (3.06, -0.03, -1.80), Yaw: 6.09°
# [INFO] Position: (3.05, -0.03, -1.80), Yaw: 6.22°
# [INFO] Position: (3.04, -0.03, -1.80), Yaw: 6.09°
# [INFO] Position: (3.04, -0.03, -1.80), Yaw: 6.09°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 6.15°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 6.15°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 6.70°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 6.70°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 6.79°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 6.79°
# [INFO] Position: (3.03, -0.02, -1.80), Yaw: 6.65°
# [INFO] Position: (3.03, -0.02, -1.80), Yaw: 6.65°
# [INFO] Position: (3.02, -0.01, -1.80), Yaw: 10.69°
# [INFO] Position: (3.02, -0.01, -1.80), Yaw: 11.16°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: 11.16°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: 12.44°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: 12.44°
# [INFO] Position: (3.02, -0.00, -1.80), Yaw: 13.20°
# [INFO] Position: (3.02, -0.00, -1.80), Yaw: 13.20°
# [INFO] Position: (3.02, -0.00, -1.80), Yaw: 12.78°
# [INFO] Position: (3.03, -0.00, -1.80), Yaw: 13.11°
# [INFO] Position: (3.03, -0.00, -1.80), Yaw: 13.11°
# [INFO] Position: (3.03, 0.00, -1.80), Yaw: 13.34°
# [INFO] Position: (3.03, 0.01, -1.80), Yaw: 13.31°
# [INFO] Position: (3.03, 0.01, -1.80), Yaw: 13.31°
# [INFO] Position: (3.03, 0.01, -1.80), Yaw: 13.59°
# [INFO] Position: (3.02, 0.01, -1.80), Yaw: 13.59°
# [INFO] Position: (3.02, 0.01, -1.80), Yaw: 13.54°
# [INFO] Position: (3.02, 0.01, -1.80), Yaw: 13.54°
# [INFO] Position: (3.01, 0.01, -1.80), Yaw: 12.97°
# [INFO] Position: (3.01, 0.01, -1.80), Yaw: 12.97°
# [INFO] Position: (3.01, 0.01, -1.80), Yaw: 12.61°
# [INFO] Position: (3.00, 0.01, -1.80), Yaw: 12.61°
# [INFO] Position: (3.00, 0.00, -1.80), Yaw: 12.74°
# [INFO] Position: (3.00, -0.00, -1.80), Yaw: 12.74°
# [INFO] Position: (3.00, -0.01, -1.80), Yaw: 13.35°
# [INFO] Position: (3.00, -0.01, -1.80), Yaw: 13.35°
# [INFO] Position: (3.00, -0.01, -1.80), Yaw: 13.81°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 13.81°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 14.11°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 14.11°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 14.41°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 14.41°
# [INFO] Position: (3.01, -0.02, -1.80), Yaw: 14.71°
# [INFO] Position: (3.01, -0.02, -1.80), Yaw: 14.71°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.05°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.60°
# [INFO] Position: (3.02, -0.01, -1.80), Yaw: 15.65°
# [INFO] Position: (3.02, -0.01, -1.80), Yaw: 15.65°
# [INFO] Position: (3.02, -0.01, -1.80), Yaw: 15.65°
# [INFO] Position: (3.02, -0.01, -1.80), Yaw: 15.65°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.66°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.66°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.98°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.98°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 16.27°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 16.07°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 16.07°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.56°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 15.56°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 14.95°
# [INFO] Position: (3.01, -0.01, -1.80), Yaw: 14.95°
# [INFO] Position: (3.01, -0.02, -1.80), Yaw: 14.12°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 14.12°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 13.45°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 13.45°
# [INFO] Position: (3.00, -0.02, -1.80), Yaw: 12.95°
# [INFO] Position: (2.99, -0.03, -1.80), Yaw: 12.59°
# [INFO] Position: (2.99, -0.03, -1.80), Yaw: 12.59°
# [INFO] Position: (2.99, -0.03, -1.80), Yaw: 11.66°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 11.50°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 11.50°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 11.71°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 11.71°
# [INFO] Position: (2.97, -0.03, -1.80), Yaw: 12.05°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 12.05°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 12.17°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 12.17°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 11.67°
# [INFO] Position: (2.96, -0.05, -1.80), Yaw: 11.67°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 10.38°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 10.38°
# [INFO] Position: (2.97, -0.04, -1.80), Yaw: 9.70°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 7.46°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 7.46°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 6.37°
# [INFO] Position: (2.98, -0.03, -1.80), Yaw: 6.37°
# [INFO] Position: (2.97, -0.03, -1.80), Yaw: 5.17°
# [INFO] Position: (2.97, -0.03, -1.80), Yaw: 5.17°
# [INFO] Position: (2.96, -0.03, -1.80), Yaw: 0.34°
# [INFO] Position: (2.94, -0.03, -1.80), Yaw: -2.23°
# [INFO] Position: (2.93, -0.04, -1.80), Yaw: -2.23°
# [INFO] Position: (2.93, -0.04, -1.80), Yaw: -9.84°
# [INFO] Position: (2.93, -0.03, -1.80), Yaw: -9.84°
# [INFO] Position: (2.92, -0.04, -1.80), Yaw: -15.80°
# [INFO] Position: (2.92, -0.04, -1.80), Yaw: -15.80°
# [INFO] Position: (2.92, -0.05, -1.80), Yaw: -23.43°
# [INFO] Position: (2.94, -0.04, -1.80), Yaw: -31.00°
# [INFO] Position: (2.95, -0.04, -1.80), Yaw: -31.00°
# [INFO] Position: (2.95, -0.04, -1.80), Yaw: -37.22°
# [INFO] Position: (2.96, -0.04, -1.80), Yaw: -37.22°
# [INFO] Position: (2.96, -0.03, -1.80), Yaw: -45.63°
# [INFO] Position: (2.97, -0.03, -1.80), Yaw: -45.63°
# [INFO] Position: (2.96, -0.02, -1.80), Yaw: -50.92°
# [INFO] Position: (2.95, -0.02, -1.80), Yaw: -50.92°
# [INFO] Position: (2.94, -0.02, -1.80), Yaw: -55.76°
# [INFO] Position: (2.93, -0.02, -1.80), Yaw: -55.76°
# [INFO] Position: (2.92, -0.02, -1.80), Yaw: -61.16°
# [INFO] Position: (2.91, -0.02, -1.80), Yaw: -61.16°
# [INFO] Position: (2.90, -0.03, -1.80), Yaw: -67.20°
# [INFO] Position: (2.89, -0.03, -1.80), Yaw: -71.09°
# [INFO] Position: (2.89, -0.03, -1.80), Yaw: -71.09°
# [INFO] Position: (2.89, -0.02, -1.80), Yaw: -73.78°
# [INFO] Position: (2.89, -0.02, -1.80), Yaw: -73.78°
# [INFO] Position: (2.90, -0.03, -1.80), Yaw: -75.60°
# [INFO] Position: (2.90, -0.03, -1.80), Yaw: -75.60°
# [INFO] Position: (2.92, -0.04, -1.80), Yaw: -76.13°
# [INFO] Position: (2.94, -0.05, -1.80), Yaw: -76.04°
# [INFO] Position: (2.95, -0.05, -1.80), Yaw: -76.04°
# [INFO] Position: (2.96, -0.05, -1.80), Yaw: -76.80°
# [INFO] Position: (2.97, -0.05, -1.80), Yaw: -76.80°
# [INFO] Position: (2.98, -0.05, -1.80), Yaw: -77.59°
# [INFO] Position: (2.98, -0.06, -1.80), Yaw: -77.59°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -77.11°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -77.11°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -76.71°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -76.71°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -76.49°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -76.49°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -76.18°
# [INFO] Position: (3.00, -0.05, -1.80), Yaw: -76.18°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -76.15°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -76.15°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -76.20°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -76.20°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -75.90°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -76.93°
# [INFO] Position: (2.99, -0.07, -1.80), Yaw: -79.08°
# [INFO] Position: (2.99, -0.07, -1.80), Yaw: -79.08°
# [INFO] Position: (3.00, -0.07, -1.80), Yaw: -81.61°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -81.61°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -84.03°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -84.03°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -86.37°
# [INFO] Position: (3.00, -0.06, -1.80), Yaw: -86.37°
# [INFO] Position: (2.99, -0.06, -1.80), Yaw: -88.46°
# [INFO] Position: (2.98, -0.07, -1.80), Yaw: -93.04°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -93.76°
# [INFO] Position: (2.97, -0.08, -1.80), Yaw: -93.76°
# [INFO] Position: (2.97, -0.08, -1.80), Yaw: -93.02°
# [INFO] Position: (2.97, -0.08, -1.80), Yaw: -93.02°
# [INFO] Position: (2.97, -0.09, -1.80), Yaw: -90.89°
# [INFO] Position: (2.97, -0.09, -1.80), Yaw: -90.33°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -90.33°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -90.05°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.95°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.95°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.86°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.86°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.74°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.74°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.67°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.78°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.78°
# [INFO] Position: (2.98, -0.08, -1.80), Yaw: -89.93°
# [INFO] Position: (2.98, -0.09, -1.80), Yaw: -89.93°
# [INFO] Position: (2.97, -0.09, -1.80), Yaw: -91.61°
# [INFO] Position: (2.93, -0.07, -1.80), Yaw: -160.65°
# [INFO] Position: (2.91, -0.05, -1.80), Yaw: -160.65°
# [INFO] Position: (2.91, -0.02, -1.80), Yaw: -164.91°
# [INFO] Position: (2.91, 0.00, -1.80), Yaw: -164.91°
# [INFO] Position: (2.92, 0.02, -1.80), Yaw: -167.05°
# [INFO] Position: (2.92, 0.03, -1.80), Yaw: -167.05°
# [INFO] Position: (2.93, 0.05, -1.80), Yaw: -167.73°
# [INFO] Position: (2.95, 0.05, -1.80), Yaw: -168.55°
# [INFO] Position: (2.96, 0.05, -1.80), Yaw: -168.55°
# [INFO] Position: (2.97, 0.05, -1.80), Yaw: -169.61°
# [INFO] Position: (2.98, 0.05, -1.80), Yaw: -169.61°
# [INFO] Position: (2.99, 0.05, -1.80), Yaw: -170.73°
# [INFO] Position: (2.99, 0.05, -1.80), Yaw: -170.73°
# [INFO] Position: (3.00, 0.06, -1.80), Yaw: -171.80°
# [INFO] Position: (3.01, 0.06, -1.80), Yaw: -171.80°
# [INFO] Position: (3.01, 0.06, -1.80), Yaw: -172.90°
# [INFO] Position: (3.02, 0.06, -1.80), Yaw: -172.90°
# [INFO] Position: (3.01, 0.06, -1.80), Yaw: -173.38°
# [INFO] Position: (3.01, 0.04, -1.80), Yaw: -173.52°
# [INFO] Position: (3.01, 0.03, -1.80), Yaw: -173.52°
# [INFO] Position: (3.01, 0.03, -1.80), Yaw: -173.65°
# [INFO] Position: (3.01, 0.02, -1.80), Yaw: -173.60°
# [INFO] Position: (3.00, 0.02, -1.80), Yaw: -173.60°
# [INFO] Position: (3.00, 0.02, -1.80), Yaw: -173.70°
# [INFO] Position: (3.00, 0.02, -1.80), Yaw: -173.82°
# [INFO] Position: (3.00, 0.01, -1.80), Yaw: -173.82°
# [INFO] Position: (3.00, 0.01, -1.80), Yaw: -173.96°
# [INFO] Position: (3.00, 0.00, -1.80), Yaw: -173.96°
# [INFO] Position: (3.00, 0.00, -1.80), Yaw: -174.27°
# [INFO] Position: (3.00, -0.00, -1.80), Yaw: -174.27°
# [INFO] Position: (3.00, -0.00, -1.80), Yaw: -174.71°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -175.32°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -175.32°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -175.97°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -175.97°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -176.37°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -176.37°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -177.00°
# [INFO] Position: (3.01, -0.00, -1.80), Yaw: -177.00°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: -177.81°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: -177.81°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: -178.77°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: -178.77°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: -179.43°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: -179.43°
# [INFO] Position: (3.01, 0.00, -1.80), Yaw: 179.27°
# [INFO] Position: (3.01, 0.01, -1.80), Yaw: 176.31°
# [INFO] Position: (3.02, 0.01, -1.80), Yaw: 176.31°
# [INFO] Position: (3.03, 0.01, -1.80), Yaw: 165.01°
# [INFO] Position: (3.04, 0.01, -1.80), Yaw: 160.02°
# [INFO] Position: (3.05, 0.01, -1.80), Yaw: 160.02°
# [INFO] Position: (3.05, 0.01, -1.80), Yaw: 154.68°
# [INFO] Position: (3.06, 0.01, -1.80), Yaw: 154.68°
# [INFO] Position: (3.06, 0.00, -1.80), Yaw: 149.78°
# [INFO] Position: (3.07, -0.00, -1.80), Yaw: 149.78°
# [INFO] Position: (3.07, -0.01, -1.80), Yaw: 144.44°
# [INFO] Position: (3.06, -0.01, -1.80), Yaw: 144.44°
# [INFO] Position: (3.07, -0.01, -1.80), Yaw: 139.39°
# [INFO] Position: (3.07, -0.01, -1.80), Yaw: 139.39°
# [INFO] Position: (3.06, -0.01, -1.80), Yaw: 98.42°
# [INFO] Position: (3.05, -0.01, -1.80), Yaw: 98.42°
# [INFO] Position: (3.04, -0.02, -1.80), Yaw: 99.52°
# [INFO] Position: (3.03, -0.02, -1.80), Yaw: 99.52°
# [INFO] Position: (3.03, -0.03, -1.80), Yaw: 100.14°
# [INFO] Position: (3.03, -0.04, -1.80), Yaw: 98.83°
# [INFO] Position: (3.03, -0.05, -1.80), Yaw: 98.83°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 97.18°
# [INFO] Position: (3.02, -0.07, -1.80), Yaw: 97.18°
# [INFO] Position: (3.02, -0.07, -1.80), Yaw: 96.81°
# [INFO] Position: (3.02, -0.07, -1.80), Yaw: 96.81°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 96.81°
# [INFO] Position: (3.03, -0.06, -1.80), Yaw: 96.81°
# [INFO] Position: (3.03, -0.05, -1.80), Yaw: 96.56°
# [INFO] Position: (3.03, -0.05, -1.80), Yaw: 96.56°
# [INFO] Position: (3.03, -0.05, -1.80), Yaw: 96.59°
# [INFO] Position: (3.03, -0.04, -1.80), Yaw: 96.59°
# [INFO] Position: (3.03, -0.04, -1.80), Yaw: 96.09°
# [INFO] Position: (3.03, -0.04, -1.80), Yaw: 96.09°
# [INFO] Position: (3.03, -0.04, -1.80), Yaw: 95.48°
# [INFO] Position: (3.03, -0.04, -1.80), Yaw: 95.48°
# [INFO] Position: (3.03, -0.05, -1.80), Yaw: 95.49°
# [INFO] Position: (3.03, -0.05, -1.80), Yaw: 95.49°
# [INFO] Position: (3.02, -0.05, -1.80), Yaw: 95.80°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 95.80°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 95.44°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 95.44°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 94.78°
# [INFO] Position: (3.02, -0.07, -1.80), Yaw: 93.84°
# [INFO] Position: (3.02, -0.06, -1.80), Yaw: 93.84°
# [INFO] Position: (3.02, -0.07, -1.80), Yaw: 93.55°
# [INFO] Position: (3.03, -0.07, -1.80), Yaw: 93.55°
# [INFO] Position: (3.03, -0.07, -1.80), Yaw: 93.50°
# [INFO] Position: (3.03, -0.07, -1.80), Yaw: 93.50°
# [INFO] Position: (3.03, -0.07, -1.80), Yaw: 93.17°
# [INFO] Position: (3.03, -0.07, -1.80), Yaw: 92.74°
# [INFO] Position: (3.04, -0.07, -1.80), Yaw: 92.74°
# [INFO] Position: (3.04, -0.06, -1.80), Yaw: 92.69°
# [INFO] Position: (3.05, -0.06, -1.80), Yaw: 92.89°
# [INFO] Position: (3.05, -0.06, -1.80), Yaw: 92.89°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 91.93°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 91.72°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 91.72°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 91.40°
# [INFO] Position: (3.06, -0.05, -1.80), Yaw: 91.40°
# [INFO] Position: (3.06, -0.06, -1.80), Yaw: 91.53°
# [INFO] Position: (3.06, -0.06, -1.80), Yaw: 91.90°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 91.90°
# [INFO] Position: (3.06, -0.08, -1.80), Yaw: 92.08°
# [INFO] Position: (3.06, -0.08, -1.80), Yaw: 92.08°
# [INFO] Position: (3.06, -0.08, -1.80), Yaw: 92.00°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.11°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.11°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.28°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.28°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.45°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.45°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 92.29°
# [INFO] Position: (3.05, -0.09, -1.80), Yaw: 92.29°
# [INFO] Position: (3.05, -0.09, -1.80), Yaw: 92.48°
# [INFO] Position: (3.05, -0.09, -1.80), Yaw: 92.48°
# [INFO] Position: (3.05, -0.09, -1.80), Yaw: 92.74°
# [INFO] Position: (3.05, -0.09, -1.80), Yaw: 93.00°
# [INFO] Position: (3.05, -0.09, -1.80), Yaw: 93.00°
# [INFO] Position: (3.06, -0.09, -1.80), Yaw: 93.16°
# [INFO] Position: (3.06, -0.08, -1.80), Yaw: 93.16°
# [INFO] Position: (3.06, -0.08, -1.80), Yaw: 93.40°
# [INFO] Position: (3.06, -0.08, -1.80), Yaw: 93.40°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 93.88°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 93.88°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 94.42°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 94.42°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 95.04°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 95.04°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 95.32°
# [INFO] Position: (3.06, -0.07, -1.80), Yaw: 95.32°
# [INFO] Position: (3.05, -0.07, -1.80), Yaw: 95.39°
# [INFO] Position: (3.05, -0.08, -1.80), Yaw: 95.39°
# [INFO] Position: (3.05, -0.08, -1.80), Yaw: 95.94°
# [INFO] Position: (3.05, -0.07, -1.80), Yaw: 96.08°
# [INFO] Position: (3.05, -0.07, -1.80), Yaw: 96.08°
