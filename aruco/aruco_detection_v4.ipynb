# %%
# v2: 해상도 높이기

# %%
# v3: 마커 여러 개 인식하고 id와 면적 (픽셀) 출력하기

# %%
# v4: aruco pose estimation

# %%
import cv2
import cv2.aruco as aruco
import numpy as np

# 🎯 카메라 캘리브레이션 값 로드 (미리 보정된 값)
calibration_matrix_path = "C:/calibration_matrix.npy"
distortion_coefficients_path = "C:/distortion_coefficients.npy"

k = np.load(calibration_matrix_path)  # 카메라 행렬
d = np.load(distortion_coefficients_path)  # 왜곡 계수
print("✅ 카메라 행렬:\n", k)
print("✅ 왜곡 계수:\n", d)

# 🎯 카메라 열기
cap = cv2.VideoCapture(1)  # 필요 시 1로 변경
cap.set(cv2.CAP_PROP_FRAME_WIDTH, 1280)
cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 720)

# 🎯 ArUco 마커 딕셔너리 설정 (4x4, 50개)
aruco_dict = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)
aruco_params = aruco.DetectorParameters()
detector = aruco.ArucoDetector(aruco_dict, aruco_params)

# 🎯 ArUco 마커 크기 (미터 단위, 0.05m = 5cm)
MARKER_SIZE = 0.05  # 5cm

def find_aruco_markers(img, draw=True):
    """ ArUco 마커 감지 및 Pose Estimation 수행 """
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    corners, ids, _ = detector.detectMarkers(gray)

    marker_info = []

    if ids is not None:
        for i, corner in enumerate(corners):
            marker_id = ids[i][0]

            # 🎯 마커의 2D 좌표 가져오기
            x1, y1 = corner[0][0]
            x2, y2 = corner[0][1]
            x3, y3 = corner[0][2]
            x4, y4 = corner[0][3]

            # 🎯 마커 면적 계산
            area = 0.5 * abs((x1*y2 + x2*y3 + x3*y4 + x4*y1) - (y1*x2 + y2*x3 + y3*x4 + y4*x1))

            # 🎯 마커의 3D 위치(Pose) 계산
            rvec, tvec, _ = aruco.estimatePoseSingleMarkers(corner, MARKER_SIZE, k, d)

            # 🎯 화면에 마커 정보 표시
            if draw:
                aruco.drawDetectedMarkers(img, [corner])
                cv2.putText(img, f"ID: {marker_id}, Area: {int(area)} px^2",
                            (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 255, 0), 2)

                # 🎯 3D 좌표 축 표시 (빨강, 초록, 파랑)
                cv2.drawFrameAxes(img, k, d, rvec, tvec, 0.03)

            # 🎯 검출된 마커 정보 저장
            marker_info.append((marker_id, area, tvec[0][0], rvec[0][0]))

    return marker_info

while True:
    ret, frame = cap.read()
    if not ret:
        print("❌ 카메라 프레임을 읽을 수 없습니다.")
        break

    markers = find_aruco_markers(frame)

    for marker in markers:
        marker_id, area, tvec, rvec = marker
        print(f"🔹 마커 ID: {marker_id}")
        print(f"   📏 면적: {int(area)} px^2")
        print(f"   📍 3D 위치: X={tvec[0]:.3f}m, Y={tvec[1]:.3f}m, Z={tvec[2]:.3f}m")
        print(f"   🔄 회전 벡터: Rx={rvec[0]:.3f}, Ry={rvec[1]:.3f}, Rz={rvec[2]:.3f}")

    # 🎯 화면 출력
    cv2.imshow("ArUco Detection", frame)

    # 'q' 또는 ESC 키로 종료
    key = cv2.waitKey(1) & 0xFF
    if key == ord('q') or key == 27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ✅ 카메라 행렬:
#  [[992.40913116   0.         605.19256803]
#  [  0.         996.28675761 343.67586117]
#  [  0.           0.           1.        ]]
# ✅ 왜곡 계수:
#  [[ 0.02206642  0.20438685 -0.00633739 -0.00140045 -0.85132748]]
# 🔹 마커 ID: 0
#    📏 면적: 36942 px^2
#    📍 3D 위치: X=-0.046m, Y=0.071m, Z=0.258m
#    🔄 회전 벡터: Rx=3.101, Ry=0.214, Rz=0.549
# 🔹 마커 ID: 0
#    📏 면적: 37665 px^2
#    📍 3D 위치: X=-0.044m, Y=0.065m, Z=0.257m
#    🔄 회전 벡터: Rx=2.639, Ry=0.048, Rz=0.044
# 🔹 마커 ID: 0
#    📏 면적: 38025 px^2
#    📍 3D 위치: X=-0.042m, Y=0.061m, Z=0.257m
#    🔄 회전 벡터: Rx=2.695, Ry=0.042, Rz=0.039
# 🔹 마커 ID: 0
#    📏 면적: 38706 px^2
#    📍 3D 위치: X=-0.040m, Y=0.056m, Z=0.257m
#    🔄 회전 벡터: Rx=2.873, Ry=0.118, Rz=0.327
# 🔹 마커 ID: 0
#    📏 면적: 38407 px^2
#    📍 3D 위치: X=-0.040m, Y=0.052m, Z=0.257m
#    🔄 회전 벡터: Rx=2.837, Ry=0.085, Rz=0.142
# 🔹 마커 ID: 0
#    📏 면적: 37939 px^2
#    📍 3D 위치: X=-0.039m, Y=0.048m, Z=0.258m
#    🔄 회전 벡터: Rx=2.825, Ry=0.090, Rz=0.153
# 🔹 마커 ID: 0
#    📏 면적: 38150 px^2
#    📍 3D 위치: X=-0.037m, Y=0.045m, Z=0.256m
#    🔄 회전 벡터: Rx=2.759, Ry=0.069, Rz=0.240
# 🔹 마커 ID: 0
#    📏 면적: 38353 px^2
#    📍 3D 위치: X=-0.036m, Y=0.043m, Z=0.256m
#    🔄 회전 벡터: Rx=2.816, Ry=0.033, Rz=0.192
# 🔹 마커 ID: 0
#    📏 면적: 38426 px^2
#    📍 3D 위치: X=-0.036m, Y=0.042m, Z=0.255m
#    🔄 회전 벡터: Rx=2.795, Ry=0.015, Rz=0.198
# 🔹 마커 ID: 0
#    📏 면적: 38815 px^2
#    📍 3D 위치: X=-0.036m, Y=0.041m, Z=0.253m
#    🔄 회전 벡터: Rx=2.770, Ry=0.012, Rz=0.166
# 🔹 마커 ID: 0
#    📏 면적: 39509 px^2
#    📍 3D 위치: X=-0.037m, Y=0.041m, Z=0.251m
#    🔄 회전 벡터: Rx=2.768, Ry=0.013, Rz=0.215
# 🔹 마커 ID: 0
#    📏 면적: 40399 px^2
#    📍 3D 위치: X=-0.038m, Y=0.040m, Z=0.247m
#    🔄 회전 벡터: Rx=2.747, Ry=0.004, Rz=0.130
# 🔹 마커 ID: 0
#    📏 면적: 41000 px^2
#    📍 3D 위치: X=-0.038m, Y=0.040m, Z=0.246m
#    🔄 회전 벡터: Rx=2.772, Ry=0.002, Rz=0.132
# 🔹 마커 ID: 0
#    📏 면적: 41796 px^2
#    📍 3D 위치: X=-0.039m, Y=0.040m, Z=0.244m
#    🔄 회전 벡터: Rx=2.765, Ry=-0.010, Rz=0.094
# 🔹 마커 ID: 0
#    📏 면적: 42102 px^2
#    📍 3D 위치: X=-0.039m, Y=0.040m, Z=0.243m
#    🔄 회전 벡터: Rx=2.785, Ry=-0.013, Rz=0.069
# 🔹 마커 ID: 0
#    📏 면적: 42500 px^2
#    📍 3D 위치: X=-0.039m, Y=0.039m, Z=0.241m
#    🔄 회전 벡터: Rx=2.742, Ry=-0.021, Rz=0.065
# 🔹 마커 ID: 0
#    📏 면적: 42696 px^2
#    📍 3D 위치: X=-0.039m, Y=0.039m, Z=0.240m
#    🔄 회전 벡터: Rx=2.759, Ry=-0.032, Rz=0.040
# 🔹 마커 ID: 0
#    📏 면적: 42885 px^2
#    📍 3D 위치: X=-0.039m, Y=0.038m, Z=0.238m
#    🔄 회전 벡터: Rx=2.724, Ry=-0.052, Rz=-0.003
# 🔹 마커 ID: 0
#    📏 면적: 43183 px^2
#    📍 3D 위치: X=-0.039m, Y=0.038m, Z=0.236m
#    🔄 회전 벡터: Rx=2.702, Ry=-0.054, Rz=-0.016
# 🔹 마커 ID: 0
#    📏 면적: 43683 px^2
#    📍 3D 위치: X=-0.039m, Y=0.038m, Z=0.234m
#    🔄 회전 벡터: Rx=2.692, Ry=-0.054, Rz=-0.056
# 🔹 마커 ID: 0
#    📏 면적: 44082 px^2
#    📍 3D 위치: X=-0.040m, Y=0.038m, Z=0.232m
#    🔄 회전 벡터: Rx=2.680, Ry=-0.058, Rz=-0.077
# 🔹 마커 ID: 0
#    📏 면적: 44183 px^2
#    📍 3D 위치: X=-0.040m, Y=0.038m, Z=0.232m
#    🔄 회전 벡터: Rx=2.681, Ry=-0.061, Rz=-0.088
# 🔹 마커 ID: 0
#    📏 면적: 44385 px^2
#    📍 3D 위치: X=-0.040m, Y=0.038m, Z=0.231m
#    🔄 회전 벡터: Rx=2.682, Ry=-0.059, Rz=-0.106
# 🔹 마커 ID: 0
#    📏 면적: 44678 px^2
#    📍 3D 위치: X=-0.040m, Y=0.038m, Z=0.229m
#    🔄 회전 벡터: Rx=2.650, Ry=-0.061, Rz=-0.097
# 🔹 마커 ID: 0
#    📏 면적: 44454 px^2
#    📍 3D 위치: X=-0.040m, Y=0.038m, Z=0.230m
#    🔄 회전 벡터: Rx=2.645, Ry=-0.063, Rz=-0.110
# 🔹 마커 ID: 0
#    📏 면적: 44664 px^2
#    📍 3D 위치: X=-0.041m, Y=0.038m, Z=0.229m
#    🔄 회전 벡터: Rx=2.633, Ry=-0.057, Rz=-0.099
# 🔹 마커 ID: 0
#    📏 면적: 44781 px^2
#    📍 3D 위치: X=-0.041m, Y=0.039m, Z=0.229m
#    🔄 회전 벡터: Rx=2.649, Ry=-0.058, Rz=-0.101
# 🔹 마커 ID: 0
#    📏 면적: 44990 px^2
#    📍 3D 위치: X=-0.041m, Y=0.039m, Z=0.229m
#    🔄 회전 벡터: Rx=2.636, Ry=-0.059, Rz=-0.090
# 🔹 마커 ID: 0
#    📏 면적: 44990 px^2
#    📍 3D 위치: X=-0.042m, Y=0.040m, Z=0.229m
#    🔄 회전 벡터: Rx=2.638, Ry=-0.059, Rz=-0.085
# 🔹 마커 ID: 0
#    📏 면적: 45206 px^2
#    📍 3D 위치: X=-0.042m, Y=0.041m, Z=0.229m
#    🔄 회전 벡터: Rx=2.643, Ry=-0.059, Rz=-0.080
# 🔹 마커 ID: 0
#    📏 면적: 45503 px^2
#    📍 3D 위치: X=-0.043m, Y=0.042m, Z=0.228m
#    🔄 회전 벡터: Rx=2.648, Ry=-0.060, Rz=-0.131
# 🔹 마커 ID: 0
#    📏 면적: 45855 px^2
#    📍 3D 위치: X=-0.044m, Y=0.043m, Z=0.228m
#    🔄 회전 벡터: Rx=2.665, Ry=-0.047, Rz=-0.117
# 🔹 마커 ID: 0
#    📏 면적: 45968 px^2
#    📍 3D 위치: X=-0.045m, Y=0.045m, Z=0.228m
#    🔄 회전 벡터: Rx=2.670, Ry=-0.048, Rz=-0.101
# 🔹 마커 ID: 0
#    📏 면적: 45985 px^2
#    📍 3D 위치: X=-0.046m, Y=0.046m, Z=0.229m
#    🔄 회전 벡터: Rx=2.691, Ry=-0.044, Rz=-0.102
# 🔹 마커 ID: 0
#    📏 면적: 45787 px^2
#    📍 3D 위치: X=-0.048m, Y=0.047m, Z=0.231m
#    🔄 회전 벡터: Rx=2.716, Ry=-0.045, Rz=-0.063
# 🔹 마커 ID: 0
#    📏 면적: 45478 px^2
#    📍 3D 위치: X=-0.048m, Y=0.047m, Z=0.232m
#    🔄 회전 벡터: Rx=2.746, Ry=-0.047, Rz=-0.071
# 🔹 마커 ID: 0
#    📏 면적: 45264 px^2
#    📍 3D 위치: X=-0.049m, Y=0.047m, Z=0.233m
#    🔄 회전 벡터: Rx=2.755, Ry=-0.048, Rz=-0.082
# 🔹 마커 ID: 0
#    📏 면적: 45484 px^2
#    📍 3D 위치: X=-0.051m, Y=0.047m, Z=0.233m
#    🔄 회전 벡터: Rx=2.739, Ry=-0.041, Rz=-0.040
# 🔹 마커 ID: 0
#    📏 면적: 45572 px^2
#    📍 3D 위치: X=-0.052m, Y=0.047m, Z=0.231m
#    🔄 회전 벡터: Rx=2.742, Ry=-0.040, Rz=-0.102
# 🔹 마커 ID: 0
#    📏 면적: 45864 px^2
#    📍 3D 위치: X=-0.053m, Y=0.047m, Z=0.230m
#    🔄 회전 벡터: Rx=2.714, Ry=-0.047, Rz=-0.121
# 🔹 마커 ID: 0
#    📏 면적: 46045 px^2
#    📍 3D 위치: X=-0.055m, Y=0.048m, Z=0.229m
#    🔄 회전 벡터: Rx=2.716, Ry=-0.053, Rz=-0.151
# 🔹 마커 ID: 0
#    📏 면적: 46493 px^2
#    📍 3D 위치: X=-0.057m, Y=0.050m, Z=0.227m
#    🔄 회전 벡터: Rx=2.727, Ry=-0.038, Rz=-0.202
# 🔹 마커 ID: 0
#    📏 면적: 46795 px^2
#    📍 3D 위치: X=-0.059m, Y=0.052m, Z=0.226m
#    🔄 회전 벡터: Rx=2.730, Ry=-0.046, Rz=-0.203
# 🔹 마커 ID: 0
#    📏 면적: 46960 px^2
#    📍 3D 위치: X=-0.061m, Y=0.055m, Z=0.227m
#    🔄 회전 벡터: Rx=2.775, Ry=-0.039, Rz=-0.194
# 🔹 마커 ID: 0
#    📏 면적: 46854 px^2
#    📍 3D 위치: X=-0.062m, Y=0.057m, Z=0.228m
#    🔄 회전 벡터: Rx=2.787, Ry=-0.043, Rz=-0.169
# 🔹 마커 ID: 0
#    📏 면적: 46847 px^2
#    📍 3D 위치: X=-0.063m, Y=0.058m, Z=0.229m
#    🔄 회전 벡터: Rx=2.801, Ry=-0.051, Rz=-0.160
# 🔹 마커 ID: 0
#    📏 면적: 41690 px^2
#    📍 3D 위치: X=-0.067m, Y=0.063m, Z=0.243m
#    🔄 회전 벡터: Rx=2.804, Ry=-0.067, Rz=-0.155
