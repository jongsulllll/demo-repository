# %% [markdown]
# <변경점>
# 1. Arcface 대신 facenet 사용함. 0.1sec 이상 잡아먹음

# %% [markdown]
# 1. 사람 + 총 + 칼 인식
# 2. Arcface를 사람마다 첫 20프레임 동안 적용(Me, NotME).
# 3. NotMe이면서 사람과 총 혹은 칼의 bounding box가 겹치는 경우에는 위험인으로 분류 -> 한 번 위험인으로 분류된 사람의 ID는 dangerous_ids로 관리됨 -> dangerous_ids 중 하나에 해당하는 사람은 위에 "Dangerous person"이라고 뜸
# 4. pose estimation을 dangerous person에 대해 적용(왼팔들기, 오른팔들기, 양팔들기)
# 5. 출력화면 사이즈를 키움
# 6. 버그수정: 초기에 무기와 교차하여 dangerous_ids에 들어갔더라도, ArcFace로 내 얼굴임이 확인되면(=나 자신이 무기를 소지한 상황) 그 사람을 위험 인물에서 제외
# 7. Kobukki robot이 dangerous_ids 내에 있는 사람을 쫓아가도록 하면 될 듯
# 8. warning 해결: pip install --upgrade albumentations
# 9. 사람인 경우에 segmentation으로 윤곽선 치기(성공)

# %%
import cv2
import numpy as np
import os
import torch
from facenet_pytorch import MTCNN, InceptionResnetV1

mtcnn = MTCNN(image_size=160, margin=0, min_face_size=20)
facenet_model = InceptionResnetV1(pretrained='vggface2').eval()

def get_facenet_embedding(image_bgr):
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
    face_crop = mtcnn(image_rgb)
    if face_crop is None:
        return None
    with torch.no_grad():
        embedding = facenet_model(face_crop.unsqueeze(0))  # (1,512)
    return embedding[0].numpy()  # shape(512,)

# 내 얼굴 사진 폴더
my_face_folder = "C:/Users/idea0/EE101/Jongsul/myface"
embeddings = []

for file in os.listdir(my_face_folder):
    if file.lower().endswith(('.jpg','.png','.jpeg')):
        path = os.path.join(my_face_folder, file)
        img = cv2.imread(path)
        if img is None:
            continue
        emb = get_facenet_embedding(img)
        if emb is not None:
            embeddings.append(emb)

if len(embeddings)==0:
    raise ValueError("No embeddings generated.")

# 평균 임베딩
avg_embedding = np.mean(embeddings, axis=0)
print("FaceNet embedding shape:", avg_embedding.shape)  # (512,)

# 저장
np.save("my_facenet_embedding.npy", avg_embedding)
print("Saved my_facenet_embedding.npy")
# Out:
# FaceNet embedding shape: (512,)
# Saved my_facenet_embedding.npy

# %%
import cv2
import mediapipe as mp
import time
import torch
import numpy as np
import warnings

from ultralytics import YOLO
from sklearn.metrics.pairwise import cosine_similarity
# from insightface.app import FaceAnalysis # ArcFace는 제거
from deep_sort_realtime.deepsort_tracker import DeepSort

# FaceNet 관련 라이브러리
from facenet_pytorch import MTCNN, InceptionResnetV1

############################
# 0) FaceNet 초기화
############################
mtcnn = MTCNN(image_size=160, margin=0, min_face_size=20)
facenet_model = InceptionResnetV1(pretrained='vggface2').eval()

def get_facenet_embedding(image_bgr):
    if image_bgr.size == 0:
        # 크기가 0인 경우 즉시 None
        return None
    
    image_rgb = cv2.cvtColor(image_bgr, cv2.COLOR_BGR2RGB)
    face_crop = mtcnn(image_rgb)

    if face_crop is None:
        return None
    with torch.no_grad():
        embedding = facenet_model(face_crop.unsqueeze(0))  # (1,512)
    return embedding[0].numpy()  # (512,)

def is_my_face(face_embedding, my_embedding, threshold=0.4):
    sim = cosine_similarity([face_embedding], [my_embedding])[0][0]
    return (sim > threshold), sim

############################
# 1) 모델 및 함수 초기화
############################
device = 'cuda' if torch.cuda.is_available() else 'cpu'

model = YOLO("C:/Users/idea0/EE101/Jongsul/Yolomodels/epoch180.pt").to(device)
model_seg = YOLO("yolov8n-seg.pt").to(device)

# face_model = YOLO("C:/Users/idea0/EE101/Jongsul/Yolomodels/best.pt").to(device)
# FaceNet으로 대체하므로 face_model 제거/미사용

# 이전 ArcFace 임베딩 대신, FaceNet 임베딩
my_face_embedding = np.load("my_facenet_embedding.npy")  # FaceNet으로 미리 생성한 임베딩

############################
# Pose: Dangerous person
############################
mp_pose = mp.solutions.pose
pose_danger = mp_pose.Pose(
    static_image_mode=True,
    model_complexity=1,
    enable_segmentation=False,
    min_detection_confidence=0.7,
    min_tracking_confidence=0.7
)
mp_drawing = mp.solutions.drawing_utils

LEFT_SHOULDER = 11
RIGHT_SHOULDER= 12
LEFT_WRIST   = 15
RIGHT_WRIST  = 16

def is_arm_raised(shoulder_y, wrist_y, threshold=0.05):
    return wrist_y < (shoulder_y - threshold)

def boxes_overlap(boxA, boxB):
    (x1A, y1A, x2A, y2A) = boxA
    (x1B, y1B, x2B, y2B) = boxB
    overlap_x = not (x2A < x1B or x2B < x1A)
    overlap_y = not (y2A < y1B or y2B < y1A)
    return overlap_x and overlap_y

############################
# 2) DeepSORT 초기화
############################
tracker = DeepSort(
    max_age=30,
    n_init=3,
    nms_max_overlap=1.0,
    embedder='mobilenet',
    half=True,
    embedder_gpu=True
)

############################
# 3) 메인 루프
############################
cap = cv2.VideoCapture(0)
if not cap.isOpened():
    print("카메라를 열 수 없습니다.")
    exit()

dangerous_ids = set()
track_me_status = {}
track_arcface_count= {}
MAX_ARCFACE_FRAMES= 20
sim = 0

window_name = "DeepSORT + YOLO(SEG) + FaceNet + Pose"
cv2.namedWindow(window_name, cv2.WINDOW_NORMAL)
cv2.resizeWindow(window_name, 960,720)

prev_time = time.time()
while True:
    ret, frame = cap.read()
    if not ret:
        print("프레임 읽기 실패!")
        break

    time1 = time.time()
    rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
    results = model(rgb_frame, conf=0.5)
    results_seg = model_seg(rgb_frame, conf=0.5)

    # YOLO detection
    det= results[0]
    boxes2 = det.boxes
    masks2 = results_seg[0].masks

    person_detections= []
    weapon_boxes= []

    if boxes2 is not None:
        for i, box in enumerate(boxes2):
            x1, y1, x2, y2= map(int, box.xyxy[0])
            class_id= int(box.cls[0])
            conf= float(box.conf[0])

            cv2.rectangle(frame, (x1,y1), (x2,y2),(0,255,0),2)
            label= f"{model.names[class_id]}: {conf:.2f}"
            cv2.putText(frame, label,(x1,y1-10),
                        cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,0,0),2)

            # 세그 윤곽선(사람만)
            if masks2 is not None and class_id==0:
                if i < len(masks2.data):
                    single_mask= masks2.data[i].cpu().numpy()
                    mask_bin= (single_mask>0.5).astype(np.uint8)
                    contours,_= cv2.findContours(mask_bin, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
                    color_seg=(0,255,255)
                    cv2.drawContours(frame,contours,-1,color_seg,2)

            # DeepSORT
            if class_id==0:
                w= x2-x1
                h= y2-y1
                person_detections.append(((x1,y1,w,h), conf,0))
            elif class_id in [1,2]:
                weapon_boxes.append((x1,y1,x2,y2))

    # DeepSORT update
    tracks= tracker.update_tracks(person_detections, frame=rgb_frame)
    tracked_boxes=[]
    for t in tracks:
        if not t.is_confirmed() or t.time_since_update>1:
            continue
        tid= t.track_id
        l,t_,r,b_= map(int,t.to_ltrb())
        tracked_boxes.append((tid,l,t_,r,b_))
        cv2.putText(frame,f"ID:{tid}", (l-10,t_-10),
                    cv2.FONT_HERSHEY_SIMPLEX,0.6,(0,255,255),2)

    # FaceNet 로직
    facenet_begintime = time.time()
    for (tid, px1, py1, px2, py2) in tracked_boxes:
        if tid not in track_me_status:
            track_me_status[tid]= False  # 기본값
        if tid not in track_arcface_count:
            track_arcface_count[tid]=0
        
        me_status= track_me_status[tid]
        #if me_status==False and track_arcface_count[tid]<MAX_ARCFACE_FRAMES:
        if True:
            
            track_arcface_count[tid]+=1
            print("running facenet...")
            # FaceNet 임베딩 추출
            # 사람 얼굴 검출 -> get_facenet_embedding
            PAD = 10
            sub_face= frame[max(0, py1-PAD):py2+PAD, max(0, px1-PAD):px2+PAD]
            if sub_face.size == 0:
                continue
            emb= get_facenet_embedding(sub_face)
            if emb is not None:
                same_person, sim= is_my_face(emb, my_face_embedding, threshold=0.4)
                if same_person:
                    track_me_status[tid]=True
                    if tid in dangerous_ids:
                        dangerous_ids.remove(tid)

        # 시각화
        if track_me_status[tid]:
            text_arc= f"          Me(sim={sim:.2f})"
            color=(0,255,0)
        else:
            text_arc= "           NotMe(sim={sim:.2f})"
            color=(0,0,255)
        cv2.putText(frame,text_arc,(px1, py1-10),
                    cv2.FONT_HERSHEY_SIMPLEX,0.6, color,2)
    facenet_endtime = time.time()
    print("facenet running time:", facenet_endtime - facenet_begintime)

    # 무기 교차 & NotMe => dangerous
    for (tid, px1, py1, px2, py2) in tracked_boxes:
        if not track_me_status[tid]:
            pbox= (px1, py1, px2, py2)
            for wb in weapon_boxes:
                if boxes_overlap(pbox, wb):
                    dangerous_ids.add(tid)
                    break

    # Dangerous => Mediapipe pose
    for (tid, px1, py1, px2, py2) in tracked_boxes:
        if tid in dangerous_ids:
            sub= frame[py1:py2, px1:px2]
            if sub.size==0:
                continue
            c_rgb= cv2.cvtColor(sub, cv2.COLOR_BGR2RGB)
            pose_result= pose_danger.process(c_rgb)
            if pose_result.pose_landmarks:
                lms= pose_result.pose_landmarks.landmark
                sub_w= px2 - px1
                sub_h= py2 - py1

                left_shoulder_y= lms[LEFT_SHOULDER].y
                right_shoulder_y=lms[RIGHT_SHOULDER].y
                left_wrist_y= lms[LEFT_WRIST].y
                right_wrist_y=lms[RIGHT_WRIST].y

                la_up= (left_wrist_y< (left_shoulder_y-0.05))
                ra_up= (right_wrist_y<(right_shoulder_y-0.05))
                if la_up and ra_up:
                    a_text= "both arms up"
                elif la_up:
                    a_text= "left arm up"
                elif ra_up:
                    a_text= "right arm up"
                else:
                    a_text= "do nothing"

                for lm in lms:
                    cx= px1+int(lm.x*sub_w)
                    cy= py1+int(lm.y*sub_h)
                    cv2.circle(frame,(cx,cy),3,(0,255,255),-1)
                cv2.putText(frame,f"Dangerous person: {a_text}",
                            (px1,py1+20),
                            cv2.FONT_HERSHEY_SIMPLEX,0.7,(0,0,255),2)

    # FPS
    # ...
    now = time.time()
    fps = 1.0/(now - prev_time)
    prev_time=now
    cv2.putText(frame,f"FPS:{fps:.2f}",(10,30),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0),2)
    
    cv2.imshow(window_name,frame)
    if cv2.waitKey(1)&0xFF==ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 personnnn, 155.0ms
# Speed: 8.0ms preprocess, 155.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 145.0ms
# Speed: 1.0ms preprocess, 145.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
# facenet running time: 0.0
#
# 0: 480x640 1 personnnn, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 120.0ms
# Speed: 3.0ms preprocess, 120.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# facenet running time: 0.0
#
# 0: 480x640 1 personnnn, 100.0ms
# Speed: 1.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 donut, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.30699992179870605
#
# 0: 480x640 1 personnnn, 97.0ms
# Speed: 3.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.0ms
# Speed: 2.0ms preprocess, 126.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.2765200138092041
#
# 0: 480x640 1 personnnn, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 131.0ms
# Speed: 5.0ms preprocess, 131.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.5905358791351318
#
# 0: 480x640 1 personnnn, 126.0ms
# Speed: 4.0ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 155.0ms
# Speed: 2.0ms preprocess, 155.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.22251582145690918
#
# 0: 480x640 1 personnnn, 126.0ms
# Speed: 3.0ms preprocess, 126.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 171.0ms
# Speed: 2.0ms preprocess, 171.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.21999907493591309
#
# 0: 480x640 1 personnnn, 110.0ms
# Speed: 2.0ms preprocess, 110.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 141.8ms
# Speed: 2.0ms preprocess, 141.8ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.16799592971801758
#
# 0: 480x640 1 personnnn, 92.0ms
# Speed: 4.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 133.0ms
# Speed: 4.0ms preprocess, 133.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.22900676727294922
#
# 0: 480x640 1 personnnn, 101.0ms
# Speed: 2.0ms preprocess, 101.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.1ms
# Speed: 2.0ms preprocess, 129.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.21299362182617188
#
# 0: 480x640 1 personnnn, 124.0ms
# Speed: 1.0ms preprocess, 124.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.1ms
# Speed: 1.0ms preprocess, 138.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.18899822235107422
#
# 0: 480x640 1 personnnn, 124.0ms
# Speed: 3.0ms preprocess, 124.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 145.1ms
# Speed: 3.0ms preprocess, 145.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.18499326705932617
#
# 0: 480x640 1 personnnn, 103.0ms
# Speed: 2.0ms preprocess, 103.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 hot dog, 141.0ms
# Speed: 3.0ms preprocess, 141.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17399811744689941
#
# 0: 480x640 1 personnnn, 107.1ms
# Speed: 3.0ms preprocess, 107.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 hot dog, 164.3ms
# Speed: 1.0ms preprocess, 164.3ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.14100217819213867
#
# 0: 480x640 1 personnnn, 97.0ms
# Speed: 2.0ms preprocess, 97.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 136.1ms
# Speed: 2.0ms preprocess, 136.1ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.1740117073059082
#
# 0: 480x640 1 personnnn, 100.0ms
# Speed: 5.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.0ms
# Speed: 2.0ms preprocess, 127.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17299866676330566
#
# 0: 480x640 1 personnnn, 108.8ms
# Speed: 3.0ms preprocess, 108.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.9ms
# Speed: 2.0ms preprocess, 129.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.18099713325500488
#
# 0: 480x640 1 personnnn, 112.0ms
# Speed: 4.0ms preprocess, 112.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.16900014877319336
#
# 0: 480x640 1 personnnn, 98.0ms
# Speed: 2.0ms preprocess, 98.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 137.0ms
# Speed: 3.0ms preprocess, 137.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.16400694847106934
#
# 0: 480x640 1 personnnn, 125.0ms
# Speed: 4.0ms preprocess, 125.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 192.0ms
# Speed: 4.0ms preprocess, 192.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.247999906539917
#
# 0: 480x640 1 personnnn, 116.0ms
# Speed: 2.0ms preprocess, 116.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 142.0ms
# Speed: 4.0ms preprocess, 142.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.1399996280670166
#
# 0: 480x640 1 personnnn, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 127.0ms
# Speed: 2.0ms preprocess, 127.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.15599322319030762
#
# 0: 480x640 1 personnnn, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.5ms
# Speed: 4.3ms preprocess, 138.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.1480088233947754
#
# 0: 480x640 1 personnnn, 109.8ms
# Speed: 3.0ms preprocess, 109.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.0ms
# Speed: 3.0ms preprocess, 140.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.1390078067779541
#
# 0: 480x640 1 personnnn, 96.0ms
# Speed: 6.0ms preprocess, 96.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 132.0ms
# Speed: 2.0ms preprocess, 132.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.16700339317321777
#
# 0: 480x640 1 personnnn, 111.0ms
# Speed: 2.0ms preprocess, 111.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 126.0ms
# Speed: 3.0ms preprocess, 126.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17999815940856934
#
# 0: 480x640 1 personnnn, 105.0ms
# Speed: 2.0ms preprocess, 105.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 141.0ms
# Speed: 3.0ms preprocess, 141.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.15199661254882812
#
# 0: 480x640 1 personnnn, 102.7ms
# Speed: 3.0ms preprocess, 102.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.0ms
# Speed: 5.0ms preprocess, 139.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.13699841499328613
#
# 0: 480x640 1 personnnn, 102.0ms
# Speed: 2.0ms preprocess, 102.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.0ms
# Speed: 3.0ms preprocess, 140.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17600226402282715
#
# 0: 480x640 1 personnnn, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.8ms
# Speed: 2.0ms preprocess, 129.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.1780409812927246
#
# 0: 480x640 1 personnnn, 121.0ms
# Speed: 3.0ms preprocess, 121.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 151.0ms
# Speed: 4.0ms preprocess, 151.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17300033569335938
#
# 0: 480x640 1 personnnn, 96.1ms
# Speed: 3.0ms preprocess, 96.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Speed: 3.0ms preprocess, 124.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.14100098609924316
#
# 0: 480x640 1 personnnn, 114.0ms
# Speed: 3.0ms preprocess, 114.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 148.0ms
# Speed: 2.0ms preprocess, 148.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.15036368370056152
#
# 0: 480x640 1 personnnn, 93.8ms
# Speed: 2.0ms preprocess, 93.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 162.0ms
# Speed: 2.0ms preprocess, 162.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.12399816513061523
#
# 0: 480x640 1 personnnn, 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 122.9ms
# Speed: 2.0ms preprocess, 122.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.16400957107543945
#
# 0: 480x640 1 personnnn, 120.4ms
# Speed: 4.0ms preprocess, 120.4ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 135.0ms
# Speed: 1.0ms preprocess, 135.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.12999701499938965
#
# 0: 480x640 1 personnnn, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 117.8ms
# Speed: 2.0ms preprocess, 117.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17999601364135742
#
# 0: 480x640 1 personnnn, 126.0ms
# Speed: 3.0ms preprocess, 126.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 118.0ms
# Speed: 2.0ms preprocess, 118.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.13599562644958496
#
# 0: 480x640 1 personnnn, 92.0ms
# Speed: 2.0ms preprocess, 92.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 129.0ms
# Speed: 2.0ms preprocess, 129.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.17385435104370117
#
# 0: 480x640 1 personnnn, 108.0ms
# Speed: 2.0ms preprocess, 108.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 138.0ms
# Speed: 1.0ms preprocess, 138.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.15700292587280273
#
# 0: 480x640 1 personnnn, 131.0ms
# Speed: 2.0ms preprocess, 131.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 151.0ms
# Speed: 1.0ms preprocess, 151.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.16700267791748047
#
# 0: 480x640 1 personnnn, 100.0ms
# Speed: 2.0ms preprocess, 100.0ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 139.0ms
# Speed: 2.0ms preprocess, 139.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.14400172233581543
#
# 0: 480x640 1 personnnn, 104.7ms
# Speed: 4.0ms preprocess, 104.7ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 140.0ms
# Speed: 2.0ms preprocess, 140.0ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.22900891304016113
#
# 0: 480x640 1 personnnn, 100.0ms
# Speed: 10.0ms preprocess, 100.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 124.0ms
# Speed: 2.0ms preprocess, 124.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
# running facenet...
# facenet running time: 0.13100719451904297

# %%
import torch
import sys

print("python version:", sys.version)
print("torch version:", torch.__version__)
print("CUDA Version:", torch.version.cuda)
print("CUDA Available:", torch.cuda.is_available())
# Out:
# python version: 3.8.5 (default, Sep  3 2020, 21:29:08) [MSC v.1916 64 bit (AMD64)]
# torch version: 1.12.1+cu116
# CUDA Version: 11.6
# CUDA Available: False

# %%
#pip install torch==1.12.1+cu116 torchvision==0.13.1+cu116 torchaudio==0.12.1 --extra-index-url https://download.pytorch.org/whl/cu116
# Out:
# ^C
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
print("사용 가능한 GPU 수:", torch.cuda.device_count())
if torch.cuda.is_available():
    print("GPU 이름:", torch.cuda.get_device_name(0))
# Out:
# 사용 가능한 GPU 수: 0
